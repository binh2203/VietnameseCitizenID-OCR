# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !wget -P /content/drive/MyDrive/yolov10/weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10n.pt
# !wget -P /content/drive/MyDrive/yolov10/weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10b.pt
# !wget -P /content/drive/MyDrive/yolov10/weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10x.pt

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 37.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...

# %% [markdown]
# ### Training model YOLOv10-N

# %%
# !yolo task=detect mode=train epochs=200 batch=8 plots=True \
model=/content/drive/MyDrive/yolov10/weights/yolov10n.pt \
data=/content/drive/MyDrive/CCCD_Detection/data.yaml \
augment=True imgsz=640 \
mosaic=1.0 mixup=0.2 hsv_h=0.1 hsv_s=0.5 hsv_v=0.5 degrees=15 \
lr0=0.01 lrf=0.1 warmup_epochs=5 \
dropout=0.3 \
project=/content/drive/MyDrive/yolov10/runs
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Training YOLOv10-B

# %%
# !yolo task=detect mode=train epochs=200 batch=8 plots=True \
model=/content/drive/MyDrive/yolov10/weights/yolov10b.pt \
data=/content/drive/MyDrive/CCCD_Detection/data.yaml \
augment=True imgsz=640 \
mosaic=1.0 mixup=0.2 hsv_h=0.1 hsv_s=0.5 hsv_v=0.5 degrees=15 \
lr0=0.01 lrf=0.1 warmup_epochs=5 \
dropout=0.3 \
project=/content/drive/MyDrive/yolov10/runs
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Training YOLOv10-X

# %%
# !yolo task=detect mode=train epochs=200 batch=8 plots=True \
model=/content/drive/MyDrive/yolov10/weights/yolov10x.pt \
data=/content/drive/MyDrive/CCCD_Detection/data.yaml \
augment=True imgsz=640 \
mosaic=1.0 mixup=0.2 hsv_h=0.1 hsv_s=0.5 hsv_v=0.5 degrees=15 \
lr0=0.01 lrf=0.1 warmup_epochs=5 \
dropout=0.3 \
project=/content/drive/MyDrive/yolov10/runs
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
